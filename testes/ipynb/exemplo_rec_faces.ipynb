# %%
"""
Stripped-down version of the face recognition example by Olivier Grisel

http://scikit-learn.org/dev/auto_examples/applications/face_recognition.html

## original shape of images: 50, 37
"""
import numpy as np
import pylab as pl
from sklearn import cross_validation, datasets, decomposition, svm

# ..
# .. load data ..
lfw_people = datasets.fetch_lfw_people(min_faces_per_person=70, resize=0.4)
perm = np.random.permutation(lfw_people.target.size)
lfw_people.data = lfw_people.data[perm]
lfw_people.target = lfw_people.target[perm]
faces = np.reshape(lfw_people.data, (lfw_people.target.shape[0], -1))
train, test = iter(cross_val.StratifiedKFold(lfw_people.target, k=4)).next()
X_train, X_test = faces[train], faces[test]
y_train, y_test = lfw_people.target[train], lfw_people.target[test]

# ..
# .. dimension reduction ..
pca = decomposition.RandomizedPCA(n_components=150, whiten=True)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# ..
# .. classification ..
clf = svm.SVC(C=5., gamma=0.001)
clf.fit(X_train_pca, y_train)

# ..
# .. predict on new images ..
for i in range(10):
    print lfw_people.target_names[clf.predict(X_test_pca[i])[0]]
    _ = pl.imshow(X_test[i].reshape(50, 37), cmap=pl.cm.gray)
    _ = raw_input()
# Out:
# WARNING:sklearn.datasets.lfw:Downloading LFW metadata: http://vis-www.cs.umass.edu/lfw/pairsDevTrain.txt
# WARNING:sklearn.datasets.lfw:Downloading LFW metadata: http://vis-www.cs.umass.edu/lfw/pairsDevTest.txt
# WARNING:sklearn.datasets.lfw:Downloading LFW metadata: http://vis-www.cs.umass.edu/lfw/pairs.txt
# WARNING:sklearn.datasets.lfw:Downloading LFW data (~200MB): http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# ...
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-13747e7cc2fa> in <module>()
#      17 lfw_people.target = lfw_people.target[perm]
#      18 faces = np.reshape(lfw_people.data, (lfw_people.target.shape[0], -1))
# ---> 19 train, test = iter(cross_val.StratifiedKFold(lfw_people.target, k=4)).next()
#      20 X_train, X_test = faces[train], faces[test]
#      21 y_train, y_test = lfw_people.target[train], lfw_people.target[test]
#
# NameError: name 'cross_val' is not defined
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
# /usr/lib/python2.7/dist-packages/scipy/misc/pilutil.py:299: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
#   image = Image.fromstring(mode, shape, strdata)
